# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tiktok = pd.read_csv("final_data.csv", low_memory=False)

# %% [markdown]
# I want to know what is the average length of a comments made on the videos in the data set
# I want to know the which user commented the most on the videos and his average response greater than the original comment size.

# %%
tiktok
# Out:
#                  comment_id  \
# 0       6816879848683438085
# 1       6816846992812015622
# 2       6816942564911628294
# 3       6816824764519301125
# 4       6816821633249001477
# ...                     ...
# 165105  6831297427954581509
# 165106  6831297361822711814
# 165107  6831297275164868613
# 165108  6842810518533652485
# 165109  6840892206023950342
#
#                                                      text  \
# 0       But are you giving him a Tesla? Because he des...
# 1                   David was just hoping for some help 😢
# 2       We ain’t forgot that time he tricked us all in...
# 3                                         get him a tesla
# 4                                        david ur so hung
# ...                                                   ...
# 165105                                      Sup I’m early
# 165106                                                 ￼￼
# 165107                                             Ayeeee
# ...

# %%
tiktok['comment_size'] = tiktok['text'].map(len)

# %%
tiktok['comment_size'].mean()
# Out:
# 31.05030585670159

# %% [markdown]
# Wanted to see the average length of comments left by users. was able to determine it to be 31 characters.

# %%
tiktok['comment_size']
# Out:
# 0          56
# 1          37
# 2          78
# 3          15
# 4          16
#          ...
# 165105     13
# 165106      2
# 165107      6
# 165108     38
# 165109    148
# Name: comment_size, Length: 165110, dtype: int64

# %%
comment_min = tiktok["comment_size"].min()
comment_min
# Out:
# 1

# %%
comment_max = tiktok['comment_size'].max()
comment_max
# Out:
# 150

# %%
comment_range = comment_max - comment_min
comment_range
# Out:
# 149

# %%
comment_size = tiktok['comment_size']

# %%
sorted_size = comment_size.sort_values().reset_index(drop=True)

# %%
sorted_size.median()
# Out:
# 26.0

# %%
sorted_size.mean()
# Out:
# 31.05030585670159

# %%
tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165110 entries, 0 to 165109
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   comment_id                    165110 non-null  int64
#  1   text                          165110 non-null  object
#  2   video_id                      165110 non-null  int64
#  3   create_time                   165110 non-null  int64
#  4   like_count                    165110 non-null  int64
#  5   status                        165110 non-null  int64
#  6   author.unique_id              165110 non-null  object
#  7   author.nickname               165110 non-null  object
#  8   author.is_private             165110 non-null  bool
#  9   author.language               165110 non-null  object
#  10  author.signature              126232 non-null  object
#  11  author.custom_verify          746 non-null     object
# ...

# %%
num_records = tiktok.shape[0]

# %%
author_data = tiktok[['author.unique_id']].copy()

# %%
counts = [1] * num_records

author_data['author_cnt'] = counts

# %%
author_count = pd.DataFrame(data=(author_data.groupby('author.unique_id', as_index=False).count()))

# %%
author_count
# Out:
#              author.unique_id  author_cnt
# 0     ....................999          20
# 1                   ......eli          16
# 2                 .....laur3n           1
# 3                .....loyalty          21
# 4        .....vibes...only..x           1
# ...                       ...         ...
# 6042                 zxp_vano          54
# 6043                   zylofc         132
# 6044                 zywcia.a         129
# 6045                    zyxn1          21
# 6046               zz.qxcv382           1
#
# [6047 rows x 2 columns]

# %%
author_count.mode()
# Out:
#              author.unique_id  author_cnt
# 0     ....................999         1.0
# 1                   ......eli         NaN
# 2                 .....laur3n         NaN
# 3                .....loyalty         NaN
# 4        .....vibes...only..x         NaN
# ...                       ...         ...
# 6042                 zxp_vano         NaN
# 6043                   zylofc         NaN
# 6044                 zywcia.a         NaN
# 6045                    zyxn1         NaN
# 6046               zz.qxcv382         NaN
#
# [6047 rows x 2 columns]

# %%
tiktok['author_nickname'].mode()
# Out:
# 0    _
# Name: author_nickname, dtype: object

# %%
tiktok['author_nickname'] = tiktok['author_nickname'].str.replace(' ','')

# %%
tiktok.rename(columns={'author.nickname':'author_nickname'}, inplace=True)

# %%
tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165110 entries, 0 to 165109
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   comment_id                    165110 non-null  int64
#  1   text                          165110 non-null  object
#  2   video_id                      165110 non-null  int64
#  3   create_time                   165110 non-null  int64
#  4   like_count                    165110 non-null  int64
#  5   status                        165110 non-null  int64
#  6   author.unique_id              165110 non-null  object
#  7   author_nickname               165110 non-null  object
#  8   author.is_private             165110 non-null  bool
#  9   author.language               165110 non-null  object
#  10  author.signature              126232 non-null  object
#  11  author.custom_verify          746 non-null     object
# ...

# %%
author = pd.DataFrame(data=(tiktok.query('author_nickname == "NessaTorres"')))

# %%
author
# Out:
#                 comment_id                                               text  \
# 31269  6879080332458115077  Attempt #1 until david notices me and I win a ...
# 31445  6879080537219301382  Attempt #5 until david notices me and I win a ...
# 31447  6879080573814554630  Attempt #6 until david notices me and I win a ...
# 31449  6879080456076771334  Attempt #4 until david notices me and I win a ...
# 31450  6879080620069994501  Attempt #7 until david notices me and I win a ...
# ...                    ...                                                ...
# 62403  6879080416419004421  Attempt #3 until david notices me and I win a ...
# 62404  6879080387306356742  Attempt #2 until david notices me and I win a ...
# 62405  6879080620069994501  Attempt #7 until david notices me and I win a ...
# 62652  6879080332458115077  Attempt #1 until david notices me and I win a ...
# 62670  6879080456076771334  Attempt #4 until david notices me and I win a ...
#
# ...

# %%
a_length = author['text'].map(len)

# %%
a_length.mean()
# Out:
# 79.0

# %% [markdown]
# I wanted to figure out who was leaving the most post on these tiktok videos and see if there average comment size was larger than the datas average and was able to conclude that comment size is larger than the entire data set
